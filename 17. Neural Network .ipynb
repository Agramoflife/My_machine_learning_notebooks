# %% [markdown]
# #In logistic regression why do we use the cross entropy function and not the mse because on using mse we will not get a convex function and we will have trouble finding global minima

# %% [markdown]
# # Neural Network

# %% [markdown]
# All the problems like the regression problems , classification problem can be solved by neural networks
# Classical machine learning involes alot on feature engineering where as neural networks can handle data with much feature engineering

# %%
It works same as the dendrites we have the inputs , the weitghs the summation funciton, the activation function and the output

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# The inputs are basically the features the weights(logistics regression parameters reference) are choose randomly at the begining it does a linear combination of features i.e Z and the z passes through activation function and gives us output, we will discuss the activation function in the coming cells

# %% [markdown]
# ## So before understanding lets revise the dy/dx what does is actually means, basically its tells us how will the function y will change if we change the value of x by a delta this will come in handy when you are understanding the d(loss_fun)/dw where w is weights so this means how will the loss function change if we change the value of w by delta
