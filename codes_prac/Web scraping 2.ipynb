# %% [markdown]
# # Web scraping 2

# %% [markdown]
# ## itunes api
# every api has it's own documentation and syntax go through it before using

# %%
import requests

# %%
base_site = "https://itunes.apple.com/search"
# Out:
# {'resultCount': 0, 'results': []}

# %%
# We can manually add parameters to the URL, as seen before
# E.G., searching for 'the beatles'
url = base_site + "?term=the+beatels&country=us" # the + sign in the the and beatels is basically a space 

# submit a GET request with parameters needed
requests.get(url).json()
# Out:
# {'resultCount': 50,
#  'results': [{'wrapperType': 'audiobook',
#    'artistId': 473923468,
#    'collectionId': 1647671866,
#    'artistName': 'Kenneth Womack',
#    'collectionName': 'Living the Beatles Legend',
#    'collectionCensoredName': 'Living the Beatles Legend',
#    'artistViewUrl': 'https://books.apple.com/us/author/kenneth-womack/id473923468?uo=4',
#    'collectionViewUrl': 'https://books.apple.com/us/audiobook/living-the-beatles-legend/id1647671866?uo=4',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/ca/c4/43/cac4430c-633e-9aa0-52fa-44cbcf5149ca/9780063248533.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/ca/c4/43/cac4430c-633e-9aa0-52fa-44cbcf5149ca/9780063248533.jpg/100x100bb.jpg',
#    'collectionPrice': 19.99,
#    'collectionExplicitness': 'notExplicit',
#    'trackCount': 1,
#    'country': 'USA',
#    'currency': 'USD',
#    'releaseDate': '2023-11-14T08:00:00Z',
# ...

# %%
url_1 = base_site + "?term=Elvis+Presley&country=us"
requests.get(url_1).ok
# Out:
# True

# %%
requests.get(url_1).json()
# Out:
# {'resultCount': 50,
#  'results': [{'wrapperType': 'audiobook',
#    'artistId': 197443,
#    'collectionId': 1297510396,
#    'amgArtistId': 5175,
#    'artistName': 'Elvis Presley',
#    'collectionName': 'Elvis Presley: The Truth About Me & Outtakes',
#    'collectionCensoredName': 'Elvis Presley: The Truth About Me & Outtakes',
#    'artistViewUrl': 'https://music.apple.com/us/artist/elvis-presley/197443?uo=4',
#    'collectionViewUrl': 'https://books.apple.com/us/audiobook/elvis-presley-the-truth-about-me-outtakes/id1297510396?uo=4',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music118/v4/4f/a6/d1/4fa6d11e-56e8-614a-843e-d2f2e1393b91/rm_image.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music118/v4/4f/a6/d1/4fa6d11e-56e8-614a-843e-d2f2e1393b91/rm_image.jpg/100x100bb.jpg',
#    'collectionPrice': 3.99,
#    'collectionExplicitness': 'notExplicit',
#    'trackCount': 1,
#    'copyright': '© 2017 One Media iP LTD',
# ...
